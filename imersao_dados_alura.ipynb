# %% [markdown]
# <a href="https://colab.research.google.com/github/Juliaocmc/imersao_dados_alura/blob/main/imersao_dados_alura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Resoluções da aula 1 da imersão dados da alura

# %%
import pandas as pd

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %% [markdown]
# ## Desafio 01:

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['tempo'].value_counts()
# Out:
# 48    8250
# 72    7792
# 24    7772
# Name: tempo, dtype: int64

# %%
dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %%
dados['droga'].value_counts()
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# 161572520       1
# fe6105bde       1
# ffe357f8f       1
# 573c787a2       1
# 0dedfb162       1
# Name: droga, Length: 3289, dtype: int64

# %% [markdown]
# **Ao explorar o value_counts de algumas variaveis, foi possível notar que no dados['droga'].value_counts(), há um total de 1866 ocorrencia.
# O que leva a pensar que, a diferença de tratamentos com e sem droga, é que existem varias outra classes de drogas e penas uma classe controle.**

# %% [markdown]
# ## Desafio 02

# %%
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %% [markdown]
# ## Desafio 03

# %%
dados['tratamento'].value_counts(normalize = True)*100
# Out:
# com_droga       92.164273
# com_controle     7.835727
# Name: tratamento, dtype: float64

# %% [markdown]
# ## Desafio 04

# %%
qtd__droga = dados['droga'].nunique()
print(f'Foram investigadas um total de {qtd__droga} drogas')
# Out:
# Foram investigadas um total de 3289 drogas

# %% [markdown]
# ## Desafio 05

# %%
https://pandas.pydata.org/docs/user_guide/indexing.html#the-query-method

# %% [markdown]
# ## Desafio 06

# %%
dados.rename(columns={'g-0': 'g0'}, inplace=True)

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# ## Desafio 07

# %%
grafico = dados['tempo'].value_counts().plot.bar(color = 'blue')
grafico.set_ylabel('Ocorrências', {'fontsize': 22})
grafico.set_xlabel('Tempo (horas)', {'fontsize': 22})
grafico.set_title('Tempo x Ocorrência', {'fontsize': 22})
# Out:
# Text(0.5, 1.0, 'Tempo x Ocorrência')

# %% [markdown]
# Desafio 08

# %% [markdown]
# 1.   Importar bibliotecas
# 2.   Importar repositorios do Git
# 3.   Verificar frequencias e proporções
# 4.   Plotar gráficos e tabelas
# 5.   Contar as ocorrências
